# %%
# %pip install -q langchain-openai python-dotenv
# Out:
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")

# %%
ai_message
# Out:
# AIMessage(content='인프런에는 다양한 주제의 강의가 있습니다. 프로그래밍 언어, 웹 개발, 데이터 분석, 디자인, 비즈니스, 마케팅, 투자 등 다양한 영역의 강의를 들을 수 있습니다. 또한 실무에서 바로 활용할 수 있는 실무 강의와 자격증 취득을 위한 강의도 제공되고 있습니다. 인프런에서 자신에게 필요한 강의를 찾아보시면 됩니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 159, 'prompt_tokens': 26, 'total_tokens': 185, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CTpmfl5jIOTfC8gfL4ywXWg5OmgKd', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--fe4a1343-4177-4c79-881c-3dd3fdf9201e-0', usage_metadata={'input_tokens': 26, 'output_tokens': 159, 'total_tokens': 185, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
